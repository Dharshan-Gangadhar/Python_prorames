# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharshan-Gangadhar/Python_prorames/blob/main/Pytho_base_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello-World")
# Out:
# Hello-World

# %%
a=20
b=30
c=a+b
print(c)
# Out:
# 50

# %%
bill=float(input())
tip=int(input())
people=int(input())
total=0
perpsn=0
tipamt=bill*(tip/100)
total=bill+tipamt
perpsn=total/people
print(f"{perpsn}")
# Out:
# 120.50
# 18
# 4
# 36
