# %% [markdown]
# <a href="https://colab.research.google.com/github/darshan75462020-eng/Python_prorames/blob/main/Pytho_base_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello-World")
# Out:
# Hello-World

# %%
a=20
b=30
c=a+b
print(c)
# Out:
# 50
